# %% [markdown]
# <table><tr>
# <td><b>Sapienza University of Rome</b><br>PhD Soft Skills 2026</td>
# </tr></table>
#
# # Notebook 0 — Warm-up
# **Two minutes.** This exists only to prove that everything works before we start.
#
# > **First: click `Copy to Drive` in the toolbar above.** Every notebook today opens read-only from GitHub — it will run, but nothing you do is saved until you copy it.

# %% [markdown]
# ### 1. Press the ▶ button on the cell below.
#
# You do not need to understand it. You need to see it produce a green tick.

# %%
print('If you can read this, Colab is working.')
print('Nothing here runs on your computer. Nothing here can break.')

import sys, platform
print()
print('Python', sys.version.split()[0], 'on', platform.system())

# %% [markdown]
# ### 2. Now let the AI write a cell for you
#
# **Copy this into the AI box** (click the empty cell below, then `Ctrl`+`Shift`+`Enter`, or the **Generate** button):
#
# ```text
# Print a friendly one-line greeting, then print today's date in a
# human-readable form, and finally print how many days remain in this year.
# ```
#
# > **The empty cell is directly below this box** — the grey one saying *Start coding or generate with AI*. Click inside it, press `Ctrl`+`Shift`+`Enter` (Mac: `Cmd`+`Shift`+`Enter`) or hover and click **Generate**, then paste the prompt. Read what it wrote before you run it — that habit is the whole point of the exercise.

# %% [markdown]
# **Nothing happening?** Two things to check, in order:
#
# 1. Did you click inside the grey *code* cell above — not on this text?
# 2. Is `Copy to Drive` still showing in the toolbar? Click it, then try again.
#
# If the **Generate** button never appears at all, say so in the chat now — not at 9:40. Everything today runs through that one button, and there is a fallback.
#
# Either way, run the cell below so you are not held up:

# %%
# Fallback: what the AI would have written for you.
from datetime import date

today = date.today()
end_of_year = date(today.year, 12, 31)

print('Hello — you are set up and ready.')
print('Today is', today.strftime('%A %d %B %Y'))
print((end_of_year - today).days, 'days remain in', today.year)

# %% [markdown]
# ### 3. That is the whole method.
#
# You described an outcome. Something else worked out how. You checked the result.
#
# You will do exactly this, on progressively more interesting problems, for the rest of the day.
#
# **If your cell produced a green tick, you are ready. Close this notebook.**
